# %% [markdown]
# <img src='https://hammondm.github.io/hltlogo1.png' style="float:right">
#
# Linguistics 531<br>
# Jackson
#
# # Survey
#
# Edit the markdown code below to give your answers. (Yes, this is a way to see if you know how to edit using markdown. Remember you can check *Help > Markdown* in the notebook menu.)
#
# 1. What's your name?
#
#    Riley Thompson
#
#    &nbsp;
#
# 1. What should I call you? (Please call me *Eric*, but if you can't get over calling an instructor by their first name, "Dr. Jackson" or "Professor Jackson" are fine.)
#
#    Riley
#
#    &nbsp;
#
# 1. What's your major and degree program? (HLT/MS, Engineering/BFA, Sculpture/PHD, etc.)
#
#    HLT/MS
#
#    &nbsp;
#
# 1. What languages do you speak and how do you know them? (*Me: English, native; German, 4 years high school; Russian, 2 years college; Mandarin, 2 years college + 12 years living there; Thai, Yang Zhuang, and Cantonese, bumbling to impolite; O'odham, fieldwork but I never really learned to speak it*)
#
#    English, native; Spanish, undergrad minor and family members; Portugese, I can fake it for about 2 minutes thanks to brazillian pop and a spanish background
#
#    &nbsp;
#
# 1. What courses have you had in computational linguistics?
#
#    Just HLT1 so far but my undergrad is in CS so I have some machine learning experience.
#
#    &nbsp;
#
# 1. What is a convolutional neural net? (You can just say "I don't know".)
#
#    A network of virtual "neurons" each of which can take in data, do a process on it then output a signal. These are arranged into complex layers that feed into each other to complete tasks like supervised learning and clustering.
#
#    &nbsp;
#
# 1. What is overfitting? (You can just say "I don't know".)
#
#    When you train a model too specifically to certain training data such that it can get really low loss scores on the training data but once you have it run on testing data it falls apart.
#
#    &nbsp;
#
# 1. What is dynamic programming? (You can just say "I don't know".)
#
#    Don't remember
#
#    &nbsp;
#
# 1. What's the last book you read for fun?
#
#    A really cool memoir called The Sound of Gravel by Ruth Wariner
#
#    &nbsp;
#
# 1. What's the last movie you saw?
#
#    The Rocky Horror Picture Show with my roommate
#
#    &nbsp;
#
# 1. What do you want to get out of this class?
#
#    I really want to feel prepared to get into the meat and bones of the program.
